# %%
import google.generativeai as genai
from datetime import date

# Set up API key
genai.configure(api_key="YourKeyHere")

today = str(date.today())
 
# Specify GenAI Model
model = genai.GenerativeModel('gemini-pro')

chat = model.start_chat()

# Set up the Gemini Pro model
gf = {
        "temperature": 0.9,
        "top_p": 1,
        "top_k": 1,
        "max_output_tokens": 128,
    } 

safety_settings=[
        {
            "category": "HARM_CATEGORY_DANGEROUS",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
            "threshold": "BLOCK_NONE",
        },
    ]


# Specify language
slang = "en-EN"

# Main function  
def main():
    global today, openaitts, model, chat, slang, gf, safety_settings 
    

    request = '''Explain how AI can assist in daily tasks'''
    response = chat.send_message(request)   
 
    #print(response)
    print(response.candidates[0].content.parts[0].text)
 
if __name__ == "__main__":
    main()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724167243.063774 2248431 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# **Daily Planning and Scheduling:**
#
# * **Calendar management:** AI assistants like Siri and Google Assistant can schedule appointments, create reminders, and suggest optimal times for meetings.
# * **Task management:** Apps like Todoist and Habitica use AI to prioritize tasks, track progress, and break down large projects into smaller, manageable chunks.
#
# **Communication and Connectivity:**
#
# * **Language translation:** AI-powered language apps like Google Translate can instantly translate text and speech, enabling communication with individuals who speak different languages.
# * **Virtual assistants:** Siri, Cortana, and Alexa can perform a variety of tasks, such as sending emails, making calls, and accessing information online.
#
# **Shopping and Errands:**
#
# * **Personalized recommendations:** AI algorithms analyze past purchases and browsing history to suggest products and services that align with users' preferences.
# * **Grocery list creation:** Apps like AnyList use AI to scan recipes and automatically create shopping lists, saving time and effort.
# * **Price comparison:** AI-powered apps like PriceGrabber and ShopSavvy help consumers find the best deals on products by comparing prices from multiple retailers.
#
# **Health and Wellness:**
#
# * **Fitness tracking:** Fitness trackers like Fitbit and Apple Watch use AI algorithms to monitor activity levels, sleep patterns, and heart rate.
# * **Symptom checker:** AI-powered symptom checkers can provide preliminary information about potential medical conditions based on users' self-reported symptoms.
# * **Nutritional analysis:** Apps like MyFitnessPal and Lose It! use AI to analyze food intake and provide personalized nutrition recommendations.
#
# **Entertainment and Leisure:**
#
# * **Music and movie recommendations:** AI algorithms analyze user preferences and provide personalized recommendations for entertainment content on platforms like Spotify and Netflix.
# * **Virtual tours:** Virtual reality and augmented reality applications use AI to create immersive virtual tours of museums, landmarks, and other locations.
# * **Gaming:** AI is used in video games to create more intelligent and challenging opponents, enhance graphics, and provide adaptive gameplay experiences.
#
# **Personal Finance Management:**
#
# * **Budgeting and tracking:** Budgeting apps like Mint and YNAB use AI algorithms to categorize transactions, identify spending patterns, and generate insights for financial planning.
# * **Investment recommendations:** Robo-advisors like Betterment and Wealthfront use AI to create personalized investment portfolios based on users' financial goals and risk tolerance.
#
# **Additional Examples:**
#
# * Transcribing audio recordings
# * Summarizing written text
# * Generating marketing content
# * Answering customer service inquiries
# * Detecting fraud and security breaches
